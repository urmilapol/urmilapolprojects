# %% [markdown]
# <a href="https://colab.research.google.com/github/urmilapol/urmilapolprojects/blob/master/pandas_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Let's load up the hotel booking data

# %%
df = pd.read_csv('/content/sample_data/hotel-booking-data.txt', delimiter='\t')
df.head()
# Out:
#          Date Company        Person Name  Room number
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0
# 2  1-Jan-2022   Leexo    Stanley Hadrill       4012.0
# 3      Hotels     NaN                NaN          NaN
# 4  1-Jan-2022  Rhyzio       Lyndell Tice       1006.0

# %%
df.describe()
# Out:
#        Room number
# count   153.000000
# mean   3079.326797
# std    1718.791186
# min    1001.000000
# 25%    2001.000000
# 50%    3008.000000
# 75%    4010.000000
# max    7002.000000

# %%
df['Company'].value_counts()
# Out:
# Company
# Leexo           3
# Quinu           3
# Fivechat        3
# Twitterlist     2
# Jayo            2
#                ..
# Twitterwire     1
# Skiba           1
# Tagpad          1
# Innojam         1
# Twitterworks    1
# Name: count, Length: 114, dtype: int64

# %%
df.dropna()
# Out:
#            Date       Company          Person Name  Room number
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0
# ..          ...           ...                  ...          ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0
#
# [134 rows x 4 columns]

# %%
df['2xRoom'] = df['Room number'] * 2

# %%
df
# Out:
#            Date       Company        Person Name  Room number   2xRoom
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
# [195 rows x 5 columns]

# %%
df2 = df.dropna()

# %%
df2.head()
# Out:
#          Date Company          Person Name  Room number  2xRoom
# 0  1-Jan-2022  Avamba    Anatole Ridehalgh       4008.0  8016.0
# 1  1-Jan-2022    Fatz      Aldrich McKevin       2002.0  4004.0
# 2  1-Jan-2022   Leexo      Stanley Hadrill       4012.0  8024.0
# 4  1-Jan-2022  Rhyzio         Lyndell Tice       1006.0  2012.0
# 5  1-Jan-2022   Eadel  Broderic Handscombe       3015.0  6030.0

# %%
df
# Out:
#            Date       Company        Person Name  Room number   2xRoom
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
# [195 rows x 5 columns]

# %%
df['Room number'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 190     True
# 191    False
# 192    False
# 193    False
# 194     True
# Name: Room number, Length: 195, dtype: bool

# %%
mask = df['Room number'].isna()

df['Text Value'] = np.where(mask, df['Date'], np.nan)
df
# Out:
#            Date       Company        Person Name  Room number   2xRoom  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
#     Text Value
# 0          NaN
# 1          NaN
# 2          NaN
# 3       Hotels
# 4          NaN
# ..         ...
# ...

# %%
df['Text Value'].fillna(method='bfill')
# Out:
# /tmp/ipykernel_1098/1257370354.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Text Value'].fillna(method='bfill')
# 0         Hotels
# 1         Hotels
# 2         Hotels
# 3         Hotels
# 4        Booking
#          ...
# 190    Cleartrip
# 191       Hotels
# 192       Hotels
# 193       Hotels
# 194       Hotels
# Name: Text Value, Length: 195, dtype: object

# %%
df
# Out:
#            Date       Company        Person Name  Room number   2xRoom  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
#     Text Value
# 0       Hotels
# 1       Hotels
# 2       Hotels
# 3       Hotels
# 4      Booking
# ..         ...
# ...

# %%
df['Text Value'] = df['Text Value'].bfill()

# %%
df
# Out:
#            Date       Company        Person Name  Room number   2xRoom  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
#     Text Value
# 0       Hotels
# 1       Hotels
# 2       Hotels
# 3       Hotels
# 4      Booking
# ..         ...
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#            Date       Company          Person Name  Room number   2xRoom  \
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0   8024.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0   2012.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0   6030.0
# ..          ...           ...                  ...          ...      ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0   2030.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0  14004.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0   2020.0
#
#     Text Value
# 0       Hotels
# 1       Hotels
# 2       Hotels
# 4      Booking
# ...

# %%
df.value_counts('Text Value')
# Out:
# Text Value
# Expedia             48
# Hotels              39
# Booking             24
# Travel Agent 007    12
# Cleartrip           11
# Name: count, dtype: int64

# %%
df3 = df.value_counts('Text Value')
df3.plot()
# Out:
# <Axes: xlabel='Text Value'>
