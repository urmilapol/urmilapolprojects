# %% [markdown]
# <a href="https://colab.research.google.com/github/urmilapol/urmilapolprojects/blob/master/plantrecognizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *

# %%
path = Path("/content/sample_data")
print(path)
for file, folder in [('ipomoeapescapre.csv', 'ipomoea'), ('xylocarpusgranatum.csv', 'xylocarpus '), ('heritieralittoralis.csv', 'heritiera'),
                     ('Acanthusilicifolius.csv', 'Acanthus'),('Rhizophoramucronata.csv', 'Rhizophora')]:
    dest = path/folder # path + '/' + folder
    dest.mkdir(parents=True, exist_ok=True)
    download_images(path/file, dest)
# Out:
# /content/sample_data

# %%
for folder in ('ipomoea', 'xylocarpus', 'heritiera', 'Acanthus', 'Rhizophora'):
    print(folder)
    verify_images(path/folder, delete=True, max_size=500)
# Out:
# ipomoea
# xylocarpus
# heritiera
# Acanthus
# Rhizophora

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train='.', valid_pct=0.2,
                                  ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['Acanthus', 'Rhizophora', 'heritiera', 'ipomoea', 'xylocarpus ']

# %%
data.show_batch(rows=3, figsize=(7, 8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Acanthus', 'Rhizophora', 'heritiera', 'ipomoea', 'xylocarpus '],
#  5,
#  640,
#  160)

# %%
learn = create_cnn(data, models.resnet34, metrics=[error_rate, accuracy])
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:109: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.432231</td>
#       <td>1.507634</td>
#       <td>0.525000</td>
#       <td>0.475000</td>
#       <td>03:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.975639</td>
#       <td>1.290160</td>
#       <td>0.406250</td>
#       <td>0.593750</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.665269</td>
#       <td>1.278633</td>
#       <td>0.381250</td>
#       <td>0.618750</td>
#       <td>03:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.444975</td>
#       <td>1.260892</td>
#       <td>0.425000</td>
#       <td>0.575000</td>
#       <td>03:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "

# %%
losses,idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
from fastai.widgets import *

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
learn.export()

# %%
img = open_image(path/'testr.jpg')
img
# Out:
# Image (3, 600, 800)

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# Category tensor(4)

# %%
img = open_image(path/'test4.jpeg')
img

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class

# %%
img = open_image(path/'test5.jpeg')
img

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class

# %%
img = open_image(path/'test5.jpeg')
img

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class

# %%
img = open_image(path/'test5.jpeg')
img

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
