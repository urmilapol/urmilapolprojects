# %% [markdown]
# <a href="https://colab.research.google.com/github/urmilapol/urmilapolprojects/blob/master/PyCaret_on_Diabetes_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pycaret.datasets import get_data
diabetes = get_data('diabetes')
# Out:
#    Number of times pregnant  ...  Class variable
# 0                         6  ...               1
# 1                         1  ...               0
# 2                         8  ...               1
# 3                         1  ...               0
# 4                         0  ...               1
#
# [5 rows x 9 columns]

# %%
# import the classification module 
from pycaret import classification
# setup the environment 
classification_setup = classification.setup(data= diabetes, target='Class variable')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_f6b9d21a_9b67_11ea_8c02_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f6b9d21a_9b67_11ea_8c02_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f6b9d21a_9b67_11ea_8c02_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f6b9d21a_9b67_11ea_8c02_0242ac1c0002row0_col1" class="data row0 col1" >4090</td>
#             </tr>
#             <tr>
#                         <th id="T_f6b9d21a_9b67_11ea_8c02_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f6b9d21a_9b67_11ea_8c02_0242ac1c0002row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
classification.compare_models()
# Out:
# <style  type="text/css" >
#     #T_06ce7250_9b68_11ea_8c02_0242ac1c0002 th {
#           text-align: left;
#     }    #T_06ce7250_9b68_11ea_8c02_0242ac1c0002row0_col0 {
#             text-align:  left;
#         }    #T_06ce7250_9b68_11ea_8c02_0242ac1c0002row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_06ce7250_9b68_11ea_8c02_0242ac1c0002row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_06ce7250_9b68_11ea_8c02_0242ac1c0002row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_06ce7250_9b68_11ea_8c02_0242ac1c0002row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_06ce7250_9b68_11ea_8c02_0242ac1c0002row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_06ce7250_9b68_11ea_8c02_0242ac1c0002row0_col6 {
#             : ;
#             text-align:  left;
# ...

# %%
classification_catb = classification.create_model('xgboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8148  0.8812  0.6842  0.7647  0.7222  0.5840
# 1       0.7222  0.7564  0.4737  0.6429  0.5455  0.3520
# 2       0.8333  0.9218  0.5789  0.9167  0.7097  0.6010
# 3       0.8148  0.8692  0.8421  0.6957  0.7619  0.6126
# 4       0.7407  0.8195  0.6842  0.6190  0.6500  0.4449
# 5       0.8148  0.8165  0.6316  0.8000  0.7059  0.5735
# 6       0.7593  0.8195  0.6316  0.6667  0.6486  0.4658
# 7       0.7358  0.7921  0.5556  0.6250  0.5882  0.3948
# 8       0.7925  0.8333  0.6111  0.7333  0.6667  0.5178
# 9       0.8113  0.9000  0.6111  0.7857  0.6875  0.5554
# Mean    0.7840  0.8410  0.6304  0.7250  0.6686  0.5102
# SD      0.0384  0.0485  0.0917  0.0894  0.0611  0.0865

# %%
tuned_xgboost = classification.tune_model('xgboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8333  0.8962  0.6316  0.8571  0.7273  0.6112
# 1       0.7407  0.7774  0.5263  0.6667  0.5882  0.4028
# 2       0.8148  0.8767  0.6842  0.7647  0.7222  0.5840
# 3       0.8148  0.8586  0.7895  0.7143  0.7500  0.6035
# 4       0.7222  0.8015  0.6316  0.6000  0.6154  0.3982
# 5       0.8333  0.8391  0.7895  0.7500  0.7692  0.6389
# 6       0.7593  0.7895  0.6316  0.6667  0.6486  0.4658
# 7       0.7358  0.8048  0.5556  0.6250  0.5882  0.3948
# 8       0.6604  0.7540  0.4444  0.5000  0.4706  0.2219
# 9       0.7547  0.8905  0.5000  0.6923  0.5806  0.4136
# Mean    0.7669  0.8288  0.6184  0.6837  0.6460  0.4735
# SD      0.0535  0.0477  0.1096  0.0932  0.0900  0.1262

# %%
# create a model
xgboost = classification.create_model('xgboost')
# AUC plot
classification.plot_model(xgboost, plot = 'auc')

# %%
# Decision Boundary
classification.plot_model(xgboost, plot = 'boundary')

# %%
# Precision Recall Curve
classification.plot_model(xgboost, plot = 'pr')

# %%
# Validation Curve
classification.plot_model(xgboost, plot = 'vc')

# %%
classification.evaluate_model(xgboost)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
# create a model
xgboost = classification.create_model('xgboost')
# summary plot
classification.interpret_model(xgboost)
# correlation plot
classification.interpret_model(xgboost, plot = 'correlation')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8148  0.8812  0.6842  0.7647  0.7222  0.5840
# 1       0.7222  0.7564  0.4737  0.6429  0.5455  0.3520
# 2       0.8333  0.9218  0.5789  0.9167  0.7097  0.6010
# 3       0.8148  0.8692  0.8421  0.6957  0.7619  0.6126
# 4       0.7407  0.8195  0.6842  0.6190  0.6500  0.4449
# 5       0.8148  0.8165  0.6316  0.8000  0.7059  0.5735
# 6       0.7593  0.8195  0.6316  0.6667  0.6486  0.4658
# 7       0.7358  0.7921  0.5556  0.6250  0.5882  0.3948
# 8       0.7925  0.8333  0.6111  0.7333  0.6667  0.5178
# 9       0.8113  0.9000  0.6111  0.7857  0.6875  0.5554
# Mean    0.7840  0.8410  0.6304  0.7250  0.6686  0.5102
# SD      0.0384  0.0485  0.0917  0.0894  0.0611  0.0865

# %%
# create a model
xgboost = classification.create_model('xgboost')
# predict test / hold-out dataset
xgboost_holdout_pred = classification.predict_model(xgboost)
# Out:
#                        Model  Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0  Extreme Gradient Boosting    0.7359  0.8152  0.6049  0.6282  0.6164  0.4151

# %%
predictions = classification.predict_model(xgboost, data = diabetes)

# %%
predictions
# Out:
#      Number of times pregnant  ...   Score
# 0                           6  ...  0.8739
# 1                           1  ...  0.0465
# 2                           8  ...  0.8175
# 3                           1  ...  0.0054
# 4                           0  ...  0.8567
# ..                        ...  ...     ...
# 763                        10  ...  0.1165
# 764                         2  ...  0.1820
# 765                         5  ...  0.0766
# 766                         1  ...  0.6787
# 767                         1  ...  0.0289
#
# [768 rows x 11 columns]
