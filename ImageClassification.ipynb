# %% [markdown]
# <a href="https://colab.research.google.com/github/urmilapol/urmilapolprojects/blob/master/ImageClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *

# %%
path = Path("/content/sample_data")
print(path)
for file, folder in [('cats.csv', 'Cats'), ('cows.csv', 'Cows'), 
                     ('dogs.csv', 'Dogs'), ('horses.csv', 'Horses')]:
    dest = path/folder # path + '/' + folder
    dest.mkdir(parents=True, exist_ok=True)
    download_images(path/file, dest)
# Out:
# /content/sample_data

# %%
for folder in ('Cats', 'Cows', 'Dogs', 'Horses'):
    print(folder)
    verify_images(path/folder, delete=True, max_size=500)
# Out:
# Cats
# Cows
# Dogs
# Horses

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train='.', valid_pct=0.2,
                                  ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['Cats', 'Cows', 'Dogs', 'Horses']

# %%
data.show_batch(rows=3, figsize=(7, 8))

# %%
from fastai.metrics import error_rate # 1 - accuracy
learn = create_cnn(data, models.resnet50, metrics=error_rate)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:109: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
defaults.device = torch.device('cuda') # makes sure the gpu is used
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.151907</td>
#       <td>0.107845</td>
#       <td>0.039062</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.666349</td>
#       <td>0.200177</td>
#       <td>0.039062</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.461466</td>
#       <td>0.141870</td>
#       <td>0.039062</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.352327</td>
#       <td>0.130615</td>
#       <td>0.046875</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze() # must be done before calling lr_find
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       46.15% [6/13 00:46<00:54]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.082534</td>
#       <td>#na#</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.067032</td>
#       <td>#na#</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.075497</td>
#       <td>#na#</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.088722</td>
#       <td>#na#</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.080648</td>
#       <td>#na#</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.091516</td>
#       <td>#na#</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='8' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [6/8 00:06<00:02 0.2145]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(4, max_lr=slice(3e-6, 3e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.107174</td>
#       <td>0.126156</td>
#       <td>0.039062</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.136765</td>
#       <td>0.132028</td>
#       <td>0.039062</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.104547</td>
#       <td>0.126749</td>
#       <td>0.031250</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.107697</td>
#       <td>0.123000</td>
#       <td>0.031250</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('animal-detection-stage-1')

# %%
from fastai.widgets import *

ds, idxs = DatasetFormatter().from_toplosses(learn)
ImageCleaner(ds, idxs, path)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
from fastai.vision import *

# %%
df = pd.read_csv('/content/sample_data/cleaned.csv', header='infer')
print(df.head())
# Out:
#                   name   label
# 0  Horses/00000047.jpg  Horses
# 1  Horses/00000113.jpg  Horses
# 2  Horses/00000108.jpg  Horses
# 3  Horses/00000030.jpg  Horses
# 4  Horses/00000129.jpg  Horses

# %%
db = (ImageList.from_df(df, path)
                   .random_split_by_pct(0.2)
                   .label_from_df()
                   .transform(get_transforms(), size=224)
                   .databunch(bs=8)).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:217: UserWarning: `random_split_by_pct` is deprecated, please use `split_by_rand_pct`.
#   warn("`random_split_by_pct` is deprecated, please use `split_by_rand_pct`.")

# %%
print(data.classes, data.c, len(data.train_ds), len(data.valid_ds))
print(db.classes, db.c, len(db.train_ds), len(db.valid_ds))
# Out:
# ['Cats', 'Cows', 'Dogs', 'Horses'] 4 512 128
# ['Cats', 'Cows', 'Dogs', 'Horses'] 4 410 102

# %%
db.show_batch()

# %%
learn.load('animal-detection-stage-1') # loading the weights
learn.data = db # replacing the data

learn.freeze()
learn.fit_one_cycle(4)

learn.unfreeze()

learn.lr_find()
learn.recorder.plot()

learn.fit_one_cycle(4, max_lr=slice(3e-6, 3e-5))
learn.save('animal-detection-stage-2')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.495836</td>
#       <td>0.098199</td>
#       <td>0.029412</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.566346</td>
#       <td>0.136879</td>
#       <td>0.019608</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.583043</td>
#       <td>0.114818</td>
#       <td>0.049020</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.471045</td>
#       <td>0.057798</td>
#       <td>0.009804</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 00:06<00:06]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.498272</td>
#       <td>#na#</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='51' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.80% [5/51 00:00<00:07 1.1773]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.345117</td>
#       <td>0.038692</td>
#       <td>0.009804</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.274915</td>
#       <td>0.068902</td>
#       <td>0.029412</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.335098</td>
#       <td>0.056889</td>
#       <td>0.019608</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.311343</td>
#       <td>0.049260</td>
#       <td>0.009804</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(15,15))
